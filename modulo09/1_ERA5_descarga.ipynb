# %% [markdown]
# ## Descarga de datos ERA5 MSLP

# %% [markdown]
# ## Importar libreria

# %%
import os
import cdsapi  # Cliente para acceder a la API de Copernicus

# %% [markdown]
# ## Codigo para descargar ERA5

# %%
# Ruta donde se guardará el archivo descargado
output_dir = '../data/ERA5/'

# Crear una instancia del cliente CDS (Climate Data Store)
client = cdsapi.Client()

# Nombre del dataset: ERA5 con variables de nivel único (superficie)
dataset = "reanalysis-era5-single-levels"

# Diccionario con la solicitud de datos
request = {
    "product_type": ["reanalysis"],  # Tipo de producto: reanálisis
    "variable": ["mean_sea_level_pressure"],  # Variable: temperatura a 2 metros
    "year": ["2023"],  # Año de los datos

    # Todos los meses del año
    "month": ["03"],

    # Todos los días del mes
    "day": [
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12",
    ],

    # Horas del día en UTC
    "time": [
        "18:00",
    ],

    "data_format": "netcdf",           # Formato de salida: NetCDF
    "download_format": "unarchived",   # Descargar sin compresión
    "area": [5, -90, -20, -68]  # Región geográfica [N, W, S, E]
}

# Ruta completa del archivo de salida
target = os.path.join(output_dir, f"ERA5_{202303}_MSLP.nc")

# Mensaje informativo
print(f"Downloading {target}...")

# Solicitar y descargar los datos
client.retrieve(dataset, request, target)

# %%
# Ruta donde se guardará el archivo descargado
output_dir = '../data/ERA5/'

# Crear una instancia del cliente CDS (Climate Data Store)
client = cdsapi.Client()

# Nombre del dataset: ERA5 con variables de nivel único (superficie)
dataset = "reanalysis-era5-single-levels"

# Diccionario con la solicitud de datos
request = {
    "product_type": ["reanalysis"],  # Tipo de producto: reanálisis
    "variable": ["geopotential"],  # Variable: temperatura a 2 metros
    "year": ["2023"],  # Año de los datos

    # Todos los meses del año
    "month": ["03"],

    # Todos los días del mes
    "day": [
        "04",],

    # Horas del día en UTC
    "time": [
        "18:00",
    ],

    "data_format": "netcdf",           # Formato de salida: NetCDF
    "download_format": "unarchived",   # Descargar sin compresión
    "area": [5, -90, -20, -68]  # Región geográfica [N, W, S, E]
}

# Ruta completa del archivo de salida
target = os.path.join(output_dir, f"ERA5_{202303}_H.nc")

# Mensaje informativo
print(f"Downloading {target}...")

# Solicitar y descargar los datos
client.retrieve(dataset, request, target)

# %%
# Ruta donde se guardará el archivo descargado
output_dir = '../data/ERA5/'

# Crear una instancia del cliente CDS (Climate Data Store)
client = cdsapi.Client()

# Nombre del dataset: ERA5 con variables de nivel único (superficie)
dataset = "reanalysis-era5-single-levels"

# Diccionario con la solicitud de datos
request = {
    "product_type": ["reanalysis"],  # Tipo de producto: reanálisis
    "variable": ["10m_u_component_of_wind"],  # Variable: temperatura a 2 metros
    "year": ["2023"],  # Año de los datos

    # Todos los meses del año
    "month": ["03"],

    # Todos los días del mes
    "day": [
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12",
    ],

    # Horas del día en UTC
    "time": [
        "18:00",
    ],

    "data_format": "netcdf",           # Formato de salida: NetCDF
    "download_format": "unarchived",   # Descargar sin compresión
    "area": [5, -90, -20, -68]  # Región geográfica [N, W, S, E]
}

# Ruta completa del archivo de salida
target = os.path.join(output_dir, f"ERA5_{202303}_U10.nc")

# Mensaje informativo
print(f"Downloading {target}...")

# Solicitar y descargar los datos
client.retrieve(dataset, request, target)

# %%
# Ruta donde se guardará el archivo descargado
output_dir = '../data/ERA5/'

# Crear una instancia del cliente CDS (Climate Data Store)
client = cdsapi.Client()

# Nombre del dataset: ERA5 con variables de nivel único (superficie)
dataset = "reanalysis-era5-single-levels"

# Diccionario con la solicitud de datos
request = {
    "product_type": ["reanalysis"],  # Tipo de producto: reanálisis
    "variable": ["10m_v_component_of_wind"],  # Variable: temperatura a 2 metros
    "year": ["2023"],  # Año de los datos

    # Todos los meses del año
    "month": ["03"],

    # Todos los días del mes
    "day": [
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12",
    ],

    # Horas del día en UTC
    "time": [
        "18:00",
    ],

    "data_format": "netcdf",           # Formato de salida: NetCDF
    "download_format": "unarchived",   # Descargar sin compresión
    "area": [5, -90, -20, -68]  # Región geográfica [N, W, S, E]
}

# Ruta completa del archivo de salida
target = os.path.join(output_dir, f"ERA5_{202303}_V10.nc")

# Mensaje informativo
print(f"Downloading {target}...")

# Solicitar y descargar los datos
client.retrieve(dataset, request, target)

# %%
# Ruta donde se guardará el archivo descargado
output_dir = '../data/ERA5/'

# Crear una instancia del cliente CDS (Climate Data Store)
client = cdsapi.Client()

# Nombre del dataset: ERA5 con variables de nivel único (superficie)
dataset = "reanalysis-era5-single-levels"

# Diccionario con la solicitud de datos
request = {
    "product_type": ["reanalysis"],  # Tipo de producto: reanálisis
    "variable": ["2m_temperature"],  # Variable: temperatura a 2 metros
    "year": ["2023"],  # Año de los datos

    # Todos los meses del año
    "month": ["03"],

    # Todos los días del mes
    "day": [
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12",
    ],

    # Horas del día en UTC
    "time": [
        "18:00",
    ],

    "data_format": "netcdf",           # Formato de salida: NetCDF
    "download_format": "unarchived",   # Descargar sin compresión
    "area": [5, -90, -20, -68]  # Región geográfica [N, W, S, E]
}

# Ruta completa del archivo de salida
target = os.path.join(output_dir, f"ERA5_{202303}_T2.nc")

# Mensaje informativo
print(f"Downloading {target}...")

# Solicitar y descargar los datos
client.retrieve(dataset, request, target)

# %%
# Ruta donde se guardará el archivo descargado
output_dir = '../data/ERA5/'

# Crear una instancia del cliente CDS (Climate Data Store)
client = cdsapi.Client()

# Nombre del dataset: ERA5 con variables de nivel único (superficie)
dataset = "reanalysis-era5-single-levels"

# Diccionario con la solicitud de datos
request = {
    "product_type": ["reanalysis"],  # Tipo de producto: reanálisis
    "variable": ["vertical_integral_of_eastward_water_vapour_flux"],  # Variable: temperatura a 2 metros
    "year": ["2023"],  # Año de los datos

    # Todos los meses del año
    "month": ["03"],

    # Todos los días del mes
    "day": [
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12",
    ],

    # Horas del día en UTC
    "time": [
        "18:00",
    ],

    "data_format": "netcdf",           # Formato de salida: NetCDF
    "download_format": "unarchived",   # Descargar sin compresión
    "area": [5, -90, -20, -68]  # Región geográfica [N, W, S, E]
}

# Ruta completa del archivo de salida
target = os.path.join(output_dir, f"ERA5_{202303}_IVTu.nc")

# Mensaje informativo
print(f"Downloading {target}...")

# Solicitar y descargar los datos
client.retrieve(dataset, request, target)

# %%
# Ruta donde se guardará el archivo descargado
output_dir = '../data/ERA5/'

# Crear una instancia del cliente CDS (Climate Data Store)
client = cdsapi.Client()

# Nombre del dataset: ERA5 con variables de nivel único (superficie)
dataset = "reanalysis-era5-single-levels"

# Diccionario con la solicitud de datos
request = {
    "product_type": ["reanalysis"],  # Tipo de producto: reanálisis
    "variable": ["vertical_integral_of_northward_water_vapour_flux"],  # Variable: temperatura a 2 metros
    "year": ["2023"],  # Año de los datos

    # Todos los meses del año
    "month": ["03"],

    # Todos los días del mes
    "day": [
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12",
    ],

    # Horas del día en UTC
    "time": [
        "18:00",
    ],

    "data_format": "netcdf",           # Formato de salida: NetCDF
    "download_format": "unarchived",   # Descargar sin compresión
    "area": [5, -90, -20, -68]  # Región geográfica [N, W, S, E]
}

# Ruta completa del archivo de salida
target = os.path.join(output_dir, f"ERA5_{202303}_IVTv.nc")

# Mensaje informativo
print(f"Downloading {target}...")

# Solicitar y descargar los datos
client.retrieve(dataset, request, target)

# %%
# Ruta donde se guardará el archivo descargado
output_dir = '../data/ERA5/'

# Crear una instancia del cliente CDS (Climate Data Store)
client = cdsapi.Client()

# Nombre del dataset: ERA5 con variables de nivel único (superficie)
dataset = "reanalysis-era5-pressure-levels"

# Diccionario con la solicitud de datos
request = {
    "product_type": ["reanalysis"],  # Tipo de producto: reanálisis
    "variable": ["geopotential"],  # Variable: temperatura a 2 metros
    "pressure_level": ["850"], # nivel de presión
    "year": ["2023"],  # Año de los datos

    # Todos los meses del año
    "month": ["03"],

    # Todos los días del mes
    "day": [
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12",
    ],

    # Horas del día en UTC
    "time": [
        "18:00",
    ],

    "data_format": "netcdf",           # Formato de salida: NetCDF
    "download_format": "unarchived",   # Descargar sin compresión
    "area": [5, -90, -20, -68]  # Región geográfica [N, W, S, E]
}

# Ruta completa del archivo de salida
target = os.path.join(output_dir, f"ERA5_{202303}_Z850.nc")

# Mensaje informativo
print(f"Downloading {target}...")

# Solicitar y descargar los datos
client.retrieve(dataset, request, target)

# %%
# Ruta donde se guardará el archivo descargado
output_dir = '../data/ERA5/'

# Crear una instancia del cliente CDS (Climate Data Store)
client = cdsapi.Client()

# Nombre del dataset: ERA5 con variables de nivel único (superficie)
dataset = "reanalysis-era5-single-levels"

# Diccionario con la solicitud de datos
request = {
    "product_type": ["reanalysis"],  # Tipo de producto: reanálisis
    "variable": ["total_precipitation"],  # Variable: temperatura a 2 metros
    "year": ["2023"],  # Año de los datos

    # Todos los meses del año
    "month": ["03"],

    # Todos los días del mes
    "day": [
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12",
    ],

    # Horas del día en UTC
    "time": [
        "00:00", "01:00", "02:00",
        "03:00", "04:00", "05:00",
        "06:00", "07:00", "08:00",
        "09:00", "10:00", "11:00",
        "12:00", "13:00", "14:00",
        "15:00", "16:00", "17:00",
        "18:00", "19:00", "20:00",
        "21:00", "22:00", "23:00"
    ],

    "data_format": "netcdf",           # Formato de salida: NetCDF
    "download_format": "unarchived",   # Descargar sin compresión
    "area": [5, -90, -20, -68]  # Región geográfica [N, W, S, E]
}

# Ruta completa del archivo de salida
target = os.path.join(output_dir, f"ERA5_{202303}_RRR.nc")

# Mensaje informativo
print(f"Downloading {target}...")

# Solicitar y descargar los datos
client.retrieve(dataset, request, target)

# %%
# Ruta donde se guardará el archivo descargado
output_dir = '../data/ERA5/'

# Crear una instancia del cliente CDS (Climate Data Store)
client = cdsapi.Client()

# Nombre del dataset: ERA5 con variables de nivel único (superficie)
dataset = "reanalysis-era5-pressure-levels"

# Diccionario con la solicitud de datos
request = {
    "product_type": ["reanalysis"],  # Tipo de producto: reanálisis
    "variable": ["specific_humidity"],  # Variable: temperatura a 2 metros
    "pressure_level": [
        "300", "350", "400",
        "450", "500", "550",
        "600", "650", "700",
        "750", "775", "800",
        "825", "850", "875",
        "900", "925", "950",
        "975", "1000"
    ],
    "year": ["2023"],  # Año de los datos

    # Todos los meses del año
    "month": ["03"],

    # Todos los días del mes
    "day": [
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12",
    ],

    # Horas del día en UTC
    "time": [
        "18:00",
    ],

    "data_format": "netcdf",           # Formato de salida: NetCDF
    "download_format": "unarchived",   # Descargar sin compresión
    "area": [5, -90, -20, -68]  # Región geográfica [N, W, S, E]
}

# Ruta completa del archivo de salida
target = os.path.join(output_dir, f"ERA5_{202303}_q.nc")

# Mensaje informativo
print(f"Downloading {target}...")

# Solicitar y descargar los datos
client.retrieve(dataset, request, target)

# %%
# Ruta donde se guardará el archivo descargado
output_dir = '../data/ERA5/'

# Crear una instancia del cliente CDS (Climate Data Store)
client = cdsapi.Client()

# Nombre del dataset: ERA5 con variables de nivel único (superficie)
dataset = "reanalysis-era5-pressure-levels"

# Diccionario con la solicitud de datos
request = {
    "product_type": ["reanalysis"],  # Tipo de producto: reanálisis
    "variable": ["u_component_of_wind"],  # Variable: temperatura a 2 metros
    "pressure_level": [
        "300", "350", "400",
        "450", "500", "550",
        "600", "650", "700",
        "750", "775", "800",
        "825", "850", "875",
        "900", "925", "950",
        "975", "1000"
    ],
    "year": ["2023"],  # Año de los datos

    # Todos los meses del año
    "month": ["03"],

    # Todos los días del mes
    "day": [
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12",
    ],

    # Horas del día en UTC
    "time": [
        "18:00",
    ],

    "data_format": "netcdf",           # Formato de salida: NetCDF
    "download_format": "unarchived",   # Descargar sin compresión
    "area": [5, -90, -20, -68]  # Región geográfica [N, W, S, E]
}

# Ruta completa del archivo de salida
target = os.path.join(output_dir, f"ERA5_{202303}_U_pl.nc")

# Mensaje informativo
print(f"Downloading {target}...")

# Solicitar y descargar los datos
client.retrieve(dataset, request, target)

# %%
# Ruta donde se guardará el archivo descargado
output_dir = '../data/ERA5/'

# Crear una instancia del cliente CDS (Climate Data Store)
client = cdsapi.Client()

# Nombre del dataset: ERA5 con variables de nivel único (superficie)
dataset = "reanalysis-era5-pressure-levels"

# Diccionario con la solicitud de datos
request = {
    "product_type": ["reanalysis"],  # Tipo de producto: reanálisis
    "variable": ["v_component_of_wind"],  # Variable: temperatura a 2 metros
    "pressure_level": [
        "300", "350", "400",
        "450", "500", "550",
        "600", "650", "700",
        "750", "775", "800",
        "825", "850", "875",
        "900", "925", "950",
        "975", "1000"
    ],
    "year": ["2023"],  # Año de los datos

    # Todos los meses del año
    "month": ["03"],

    # Todos los días del mes
    "day": [
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12",
    ],

    # Horas del día en UTC
    "time": [
        "18:00",
    ],

    "data_format": "netcdf",           # Formato de salida: NetCDF
    "download_format": "unarchived",   # Descargar sin compresión
    "area": [5, -90, -20, -68]  # Región geográfica [N, W, S, E]
}

# Ruta completa del archivo de salida
target = os.path.join(output_dir, f"ERA5_{202303}_V_pl.nc")

# Mensaje informativo
print(f"Downloading {target}...")

# Solicitar y descargar los datos
client.retrieve(dataset, request, target)

# %%
# Ruta donde se guardará el archivo descargado
output_dir = '../data/ERA5/'

# Crear una instancia del cliente CDS (Climate Data Store)
client = cdsapi.Client()

# Nombre del dataset: ERA5 con variables de nivel único (superficie)
dataset = "reanalysis-era5-pressure-levels"

# Diccionario con la solicitud de datos
request = {
    "product_type": ["reanalysis"],  # Tipo de producto: reanálisis
    "variable": ["vertical_velocity"],  # Variable: temperatura a 2 metros
    "pressure_level": [
        "300", "350", "400",
        "450", "500", "550",
        "600", "650", "700",
        "750", "775", "800",
        "825", "850", "875",
        "900", "925", "950",
        "975", "1000"
    ],
    "year": ["2023"],  # Año de los datos

    # Todos los meses del año
    "month": ["03"],

    # Todos los días del mes
    "day": [
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12",
    ],

    # Horas del día en UTC
    "time": [
        "18:00",
    ],

    "data_format": "netcdf",           # Formato de salida: NetCDF
    "download_format": "unarchived",   # Descargar sin compresión
    "area": [5, -90, -20, -68]  # Región geográfica [N, W, S, E]
}

# Ruta completa del archivo de salida
target = os.path.join(output_dir, f"ERA5_{202303}_W_pl.nc")

# Mensaje informativo
print(f"Downloading {target}...")

# Solicitar y descargar los datos
client.retrieve(dataset, request, target)

# %%
# Ruta donde se guardará el archivo descargado
output_dir = '../data/ERA5/'

# Crear una instancia del cliente CDS (Climate Data Store)
client = cdsapi.Client()

# Nombre del dataset: ERA5 con variables de nivel único (superficie)
dataset = "reanalysis-era5-pressure-levels"

# Diccionario con la solicitud de datos
request = {
    "product_type": ["reanalysis"],  # Tipo de producto: reanálisis
    "variable": ["temperature"],  # Variable: temperatura a 2 metros
    "pressure_level": [
        "300", "350", "400",
        "450", "500", "550",
        "600", "650", "700",
        "750", "775", "800",
        "825", "850", "875",
        "900", "925", "950",
        "975", "1000"
    ],
    "year": ["2023"],  # Año de los datos

    # Todos los meses del año
    "month": ["03"],

    # Todos los días del mes
    "day": [
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12",
    ],

    # Horas del día en UTC
    "time": [
        "18:00",
    ],

    "data_format": "netcdf",           # Formato de salida: NetCDF
    "download_format": "unarchived",   # Descargar sin compresión
    "area": [5, -90, -20, -68]  # Región geográfica [N, W, S, E]
}

# Ruta completa del archivo de salida
target = os.path.join(output_dir, f"ERA5_{202303}_T_pl.nc")

# Mensaje informativo
print(f"Downloading {target}...")

# Solicitar y descargar los datos
client.retrieve(dataset, request, target)
