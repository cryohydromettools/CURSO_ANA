# %% [markdown]
# # Usando Matplotlib

# %% [markdown]
# ## Importar librerías

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Crear datos com numpy

# %%
times = np.array(
    [
        93.0,
        96.0,
        99.0,
        102.0,
        105.0,
        108.0,
        111.0,
        114.0,
        117.0,
        120.0,
        123.0,
        126.0,
        129.0,
        132.0,
        135.0,
        138.0,
        141.0,
        144.0,
        147.0,
        150.0,
        153.0,
        156.0,
        159.0,
        162.0,
    ]
)
temps = np.array(
    [
        310.7,
        308.0,
        296.4,
        289.5,
        288.5,
        287.1,
        301.1,
        308.3,
        311.5,
        305.1,
        295.6,
        292.4,
        290.4,
        289.1,
        299.4,
        307.9,
        316.6,
        293.9,
        291.2,
        289.8,
        287.1,
        285.8,
        303.3,
        310.0,
    ]
)

# %% [markdown]
# ## Imprimir varibles

# %%
print(times)
print(temps)
# Out:
# [ 93.  96.  99. 102. 105. 108. 111. 114. 117. 120. 123. 126. 129. 132.
#  135. 138. 141. 144. 147. 150. 153. 156. 159. 162.]
# [310.7 308.  296.4 289.5 288.5 287.1 301.1 308.3 311.5 305.1 295.6 292.4
#  290.4 289.1 299.4 307.9 316.6 293.9 291.2 289.8 287.1 285.8 303.3 310. ]

# %% [markdown]
# ## Hacer una Figura

# %%
# Crear una figura
fig = plt.figure(figsize=(10, 5))

# Solicitar, de una cuadrícula de 1x1 gráficos, el primer eje.
ax = fig.add_subplot(1, 1, 1)

# Graficar los tiempos como variable en el eje x y las temperaturas como variable en el eje y
ax.plot(times, temps)

# Agregar etiquetas al gráfico
ax.set_xlabel('Tiempo')
ax.set_ylabel('Temperatura (°K)')

ax.set_title('Figura de Temperatura')

ax.set_ylim(280, 320)
# Out:
# (280.0, 320.0)

# %% [markdown]
# ## Crear un nuevo vector de datos

# %%
temps_1000 = np.array(
    [
        316.0,
        316.3,
        308.9,
        304.0,
        302.0,
        300.8,
        306.2,
        309.8,
        313.5,
        313.3,
        308.3,
        304.9,
        301.0,
        299.2,
        302.6,
        309.0,
        311.8,
        304.7,
        304.6,
        301.8,
        300.6,
        299.9,
        306.3,
        311.3,
    ]
)

# %%
## imprimir variable
temps_1000
# Out:
# array([316. , 316.3, 308.9, 304. , 302. , 300.8, 306.2, 309.8, 313.5,
#        313.3, 308.3, 304.9, 301. , 299.2, 302.6, 309. , 311.8, 304.7,
#        304.6, 301.8, 300.6, 299.9, 306.3, 311.3])

# %%
# Crear una figura
fig = plt.figure(figsize=(10, 5))

# Solicitar, de una cuadrícula de 1x1 gráficos, el primer eje
ax = fig.add_subplot(1, 1, 1)

# Graficar los tiempos como variable en el eje x y las temperaturas como variable en el eje y
ax.plot(times, temps, label='T2')
ax.plot(times, temps_1000, label='T_1000')

# Agregar etiquetas al gráfico
ax.set_xlabel('Tiempo')
ax.set_ylabel('Temperatura (°K)')

# Título del gráfico
ax.set_title('Figura de Temperatura')

# Definir los límites del eje y
ax.set_ylim(280, 325)

# Agregar una leyenda en la esquina superior izquierda del gráfico
ax.legend(loc='upper left', ncol=2)

# Agregar líneas de cuadrícula
ax.grid(True)
